# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 627

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zanatepec
# City not found. Skipping...
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | kokkola
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | pevek
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | chincha alta
# Processing Record 14 of Set 1 | rocha
# Processing Record 15 of Set 1 | dimitrovgrad
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | maragogi
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | te anau
# Processing Record 20 of Set 1 | viedma
# Processing Record 21 of Set 1 | portland
# Processing Record 22 of Set 1 | umm kaddadah
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 25 of Set 1 | buon me thuot
# City not found. Skipping...
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | dali
# Processing Record 28 of Set 1 | puri
# Processing Record 29 of Set 1 | itacarambi
# Processing Record 30 of Set 1 | lipari
# Processing Record 31 of Set 1 | westpunt
# City not found. Skipping...
# Processing Record 32 of Set 1 | gao
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | faya
# Processing Record 35 of Set 1 | husavik
# Processing Record 36 of Set 1 | omsukchan
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | constitucion
# Processing Record 39 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | nichinan
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | avera
# Processing Record 47 of Set 1 | noyemberyan
# Processing Record 48 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | gigmoto
# Processing Record 1 of Set 2 | srednekolymsk
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 2 | vila do maio
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | prado
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | lugovoy
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | faanui
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | pachino
# Processing Record 14 of Set 2 | acapulco
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | san patricio
# Processing Record 19 of Set 2 | bay roberts
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | mangrol
# Processing Record 22 of Set 2 | brantford
# Processing Record 23 of Set 2 | makakilo city
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | nuuk
# Processing Record 28 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 2 | eureka
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | aklavik
# Processing Record 33 of Set 2 | eisiskes
# Processing Record 34 of Set 2 | kavaratti
# Processing Record 35 of Set 2 | comodoro rivadavia
# Processing Record 36 of Set 2 | ulladulla
# Processing Record 37 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 2 | omboue
# Processing Record 39 of Set 2 | busselton
# Processing Record 40 of Set 2 | hastings
# Processing Record 41 of Set 2 | egvekinot
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | hagere selam
# Processing Record 44 of Set 2 | kostomuksha
# Processing Record 45 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | nabire
# Processing Record 1 of Set 3 | tasiilaq
# Processing Record 2 of Set 3 | kargalinskaya
# Processing Record 3 of Set 3 | tancanhuitz
# Processing Record 4 of Set 3 | nema
# Processing Record 5 of Set 3 | brigantine
# Processing Record 6 of Set 3 | pacific grove
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | nelson bay
# Processing Record 9 of Set 3 | roebourne
# Processing Record 10 of Set 3 | nuevitas
# Processing Record 11 of Set 3 | hofn
# Processing Record 12 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | russell
# Processing Record 15 of Set 3 | santa isabel do rio negro
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | mogadishu
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 3 | chibombo
# Processing Record 23 of Set 3 | yibin
# Processing Record 24 of Set 3 | lazaro cardenas
# Processing Record 25 of Set 3 | ballina
# Processing Record 26 of Set 3 | beaverlodge
# Processing Record 27 of Set 3 | yulara
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | toamasina
# Processing Record 30 of Set 3 | ilam
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | fairbanks
# Processing Record 33 of Set 3 | mastic beach
# Processing Record 34 of Set 3 | vila velha
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | pomabamba
# Processing Record 37 of Set 3 | morozovsk
# Processing Record 38 of Set 3 | riyadh
# Processing Record 39 of Set 3 | bilibino
# Processing Record 40 of Set 3 | alofi
# Processing Record 41 of Set 3 | luebo
# Processing Record 42 of Set 3 | salalah
# Processing Record 43 of Set 3 | torbay
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | dikson
# Processing Record 47 of Set 3 | moose factory
# Processing Record 48 of Set 3 | komsomolskiy
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | deputatskiy
# Processing Record 1 of Set 4 | sfantu gheorghe
# Processing Record 2 of Set 4 | nago
# Processing Record 3 of Set 4 | shubarkuduk
# Processing Record 4 of Set 4 | kharp
# Processing Record 5 of Set 4 | pangody
# Processing Record 6 of Set 4 | talnakh
# Processing Record 7 of Set 4 | socorro
# Processing Record 8 of Set 4 | sinop
# Processing Record 9 of Set 4 | makung
# City not found. Skipping...
# Processing Record 10 of Set 4 | coihaique
# Processing Record 11 of Set 4 | caravelas
# Processing Record 12 of Set 4 | punta arenas
# Processing Record 13 of Set 4 | nome
# Processing Record 14 of Set 4 | vostok
# Processing Record 15 of Set 4 | la seyne-sur-mer
# Processing Record 16 of Set 4 | itarema
# Processing Record 17 of Set 4 | ozu
# Processing Record 18 of Set 4 | narsaq
# Processing Record 19 of Set 4 | victor harbor
# Processing Record 20 of Set 4 | varhaug
# Processing Record 21 of Set 4 | daru
# Processing Record 22 of Set 4 | atherton
# Processing Record 23 of Set 4 | bandarbeyla
# Processing Record 24 of Set 4 | mahebourg
# Processing Record 25 of Set 4 | geraldton
# Processing Record 26 of Set 4 | biak
# Processing Record 27 of Set 4 | kibala
# Processing Record 28 of Set 4 | gat
# Processing Record 29 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 4 | chaohu
# Processing Record 31 of Set 4 | basco
# Processing Record 32 of Set 4 | sulphur springs
# Processing Record 33 of Set 4 | okmulgee
# Processing Record 34 of Set 4 | bethel
# Processing Record 35 of Set 4 | zhangye
# Processing Record 36 of Set 4 | kununurra
# Processing Record 37 of Set 4 | coquimbo
# Processing Record 38 of Set 4 | arkhangelsk
# Processing Record 39 of Set 4 | bambous virieux
# Processing Record 40 of Set 4 | sitka
# Processing Record 41 of Set 4 | orito
# Processing Record 42 of Set 4 | opuwo
# Processing Record 43 of Set 4 | kloulklubed
# Processing Record 44 of Set 4 | bonn
# Processing Record 45 of Set 4 | touros
# Processing Record 46 of Set 4 | port blair
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | cockburn town
# Processing Record 49 of Set 4 | qaanaaq
# Processing Record 50 of Set 4 | najran
# Processing Record 1 of Set 5 | rutul
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | alice springs
# Processing Record 4 of Set 5 | pogranichnyy
# Processing Record 5 of Set 5 | asau
# Processing Record 6 of Set 5 | sibu
# Processing Record 7 of Set 5 | severo-kurilsk
# Processing Record 8 of Set 5 | east london
# Processing Record 9 of Set 5 | buraydah
# Processing Record 10 of Set 5 | oktyabrskoye
# Processing Record 11 of Set 5 | quatre cocos
# Processing Record 12 of Set 5 | katangli
# Processing Record 13 of Set 5 | freeport
# Processing Record 14 of Set 5 | vilyuysk
# Processing Record 15 of Set 5 | kirovskiy
# Processing Record 16 of Set 5 | baniachang
# Processing Record 17 of Set 5 | kavieng
# Processing Record 18 of Set 5 | tuktoyaktuk
# Processing Record 19 of Set 5 | ishigaki
# Processing Record 20 of Set 5 | sorgun
# Processing Record 21 of Set 5 | muros
# Processing Record 22 of Set 5 | tortoli
# Processing Record 23 of Set 5 | marabba
# Processing Record 24 of Set 5 | kalmunai
# Processing Record 25 of Set 5 | mnogovershinnyy
# Processing Record 26 of Set 5 | piraquara
# Processing Record 27 of Set 5 | imbituba
# Processing Record 28 of Set 5 | pangkalanbuun
# Processing Record 29 of Set 5 | mehamn
# Processing Record 30 of Set 5 | razole
# Processing Record 31 of Set 5 | lompoc
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | vanimo
# Processing Record 34 of Set 5 | carnarvon
# Processing Record 35 of Set 5 | humaita
# Processing Record 36 of Set 5 | lisakovsk
# Processing Record 37 of Set 5 | flinders
# Processing Record 38 of Set 5 | iracoubo
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | fuerte olimpo
# Processing Record 41 of Set 5 | mangit
# Processing Record 42 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 5 | manakara
# Processing Record 44 of Set 5 | ardesen
# Processing Record 45 of Set 5 | moron
# Processing Record 46 of Set 5 | klaksvik
# Processing Record 47 of Set 5 | cabedelo
# Processing Record 48 of Set 5 | armeria
# Processing Record 49 of Set 5 | izhma
# Processing Record 50 of Set 5 | xining
# Processing Record 1 of Set 6 | bafra
# Processing Record 2 of Set 6 | sura
# Processing Record 3 of Set 6 | dunedin
# Processing Record 4 of Set 6 | khash
# Processing Record 5 of Set 6 | lasa
# Processing Record 6 of Set 6 | lata
# Processing Record 7 of Set 6 | san andres
# Processing Record 8 of Set 6 | kenai
# Processing Record 9 of Set 6 | jumla
# Processing Record 10 of Set 6 | erdenet
# Processing Record 11 of Set 6 | bhind
# Processing Record 12 of Set 6 | camapua
# Processing Record 13 of Set 6 | khairpur nathan shah
# Processing Record 14 of Set 6 | fortuna
# Processing Record 15 of Set 6 | marsh harbour
# Processing Record 16 of Set 6 | antioquia
# Processing Record 17 of Set 6 | walvis bay
# Processing Record 18 of Set 6 | pangnirtung
# Processing Record 19 of Set 6 | bajil
# Processing Record 20 of Set 6 | kichera
# Processing Record 21 of Set 6 | rodino
# Processing Record 22 of Set 6 | abakaliki
# Processing Record 23 of Set 6 | sambava
# Processing Record 24 of Set 6 | zarya
# Processing Record 25 of Set 6 | saint-paul
# Processing Record 26 of Set 6 | valparaiso
# Processing Record 27 of Set 6 | kapoeta
# Processing Record 28 of Set 6 | kokopo
# Processing Record 29 of Set 6 | bengkulu
# Processing Record 30 of Set 6 | kaitangata
# Processing Record 31 of Set 6 | souillac
# Processing Record 32 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 6 | benguela
# Processing Record 35 of Set 6 | sogne
# Processing Record 36 of Set 6 | lagoa
# Processing Record 37 of Set 6 | beloha
# Processing Record 38 of Set 6 | puerto carreno
# Processing Record 39 of Set 6 | sabang
# Processing Record 40 of Set 6 | harper
# Processing Record 41 of Set 6 | noumea
# Processing Record 42 of Set 6 | kawalu
# Processing Record 43 of Set 6 | kefamenanu
# Processing Record 44 of Set 6 | yichun
# Processing Record 45 of Set 6 | berlevag
# Processing Record 46 of Set 6 | naze
# Processing Record 47 of Set 6 | ilulissat
# Processing Record 48 of Set 6 | hamilton
# Processing Record 49 of Set 6 | wewak
# Processing Record 50 of Set 6 | barrow
# Processing Record 1 of Set 7 | la tuque
# Processing Record 2 of Set 7 | arkadak
# Processing Record 3 of Set 7 | auki
# Processing Record 4 of Set 7 | itupiranga
# Processing Record 5 of Set 7 | pita
# Processing Record 6 of Set 7 | misasi
# Processing Record 7 of Set 7 | saint-louis
# Processing Record 8 of Set 7 | brazzaville
# Processing Record 9 of Set 7 | kupang
# Processing Record 10 of Set 7 | batagay-alyta
# Processing Record 11 of Set 7 | dubai
# Processing Record 12 of Set 7 | taltal
# Processing Record 13 of Set 7 | la ronge
# Processing Record 14 of Set 7 | airai
# Processing Record 15 of Set 7 | inhambane
# Processing Record 16 of Set 7 | namatanai
# Processing Record 17 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 7 | hof
# Processing Record 19 of Set 7 | karmala
# Processing Record 20 of Set 7 | itamaraca
# Processing Record 21 of Set 7 | coracora
# Processing Record 22 of Set 7 | snezhnogorsk
# Processing Record 23 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 24 of Set 7 | muisne
# Processing Record 25 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 7 | whitehorse
# Processing Record 27 of Set 7 | cabo san lucas
# Processing Record 28 of Set 7 | grand forks
# Processing Record 29 of Set 7 | kilakarai
# Processing Record 30 of Set 7 | bubaque
# Processing Record 31 of Set 7 | san policarpo
# Processing Record 32 of Set 7 | grindavik
# Processing Record 33 of Set 7 | gatton
# Processing Record 34 of Set 7 | tecolutla
# Processing Record 35 of Set 7 | orbetello
# Processing Record 36 of Set 7 | san martin
# Processing Record 37 of Set 7 | port hedland
# Processing Record 38 of Set 7 | qaqortoq
# Processing Record 39 of Set 7 | bima
# Processing Record 40 of Set 7 | bom jesus
# Processing Record 41 of Set 7 | port-cartier
# Processing Record 42 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 7 | westport
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | ostrovnoy
# Processing Record 46 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 7 | shelburne
# Processing Record 48 of Set 7 | slave lake
# Processing Record 49 of Set 7 | el ejido
# Processing Record 50 of Set 7 | esperance
# Processing Record 1 of Set 8 | khon kaen
# Processing Record 2 of Set 8 | inirida
# Processing Record 3 of Set 8 | grand gaube
# Processing Record 4 of Set 8 | tessalit
# Processing Record 5 of Set 8 | leningradskiy
# Processing Record 6 of Set 8 | aykhal
# Processing Record 7 of Set 8 | dauphin
# Processing Record 8 of Set 8 | ararangua
# Processing Record 9 of Set 8 | lekoni
# Processing Record 10 of Set 8 | montero
# Processing Record 11 of Set 8 | dingle
# Processing Record 12 of Set 8 | lodja
# Processing Record 13 of Set 8 | alvorada
# Processing Record 14 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 8 | summerland
# Processing Record 16 of Set 8 | honiara
# Processing Record 17 of Set 8 | tahta
# Processing Record 18 of Set 8 | poum
# Processing Record 19 of Set 8 | cascais
# Processing Record 20 of Set 8 | kaspiysk
# Processing Record 21 of Set 8 | khorramshahr
# Processing Record 22 of Set 8 | bodden town
# Processing Record 23 of Set 8 | yurty
# Processing Record 24 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 8 | sioux lookout
# Processing Record 26 of Set 8 | kendari
# Processing Record 27 of Set 8 | korgen
# Processing Record 28 of Set 8 | mushie
# Processing Record 29 of Set 8 | sokolskoye
# Processing Record 30 of Set 8 | mount isa
# Processing Record 31 of Set 8 | port elizabeth
# Processing Record 32 of Set 8 | tomatlan
# Processing Record 33 of Set 8 | columbus
# Processing Record 34 of Set 8 | brae
# Processing Record 35 of Set 8 | livingston
# Processing Record 36 of Set 8 | saldanha
# Processing Record 37 of Set 8 | acara
# Processing Record 38 of Set 8 | koutsouras
# Processing Record 39 of Set 8 | bilma
# Processing Record 40 of Set 8 | rio gallegos
# Processing Record 41 of Set 8 | forio
# Processing Record 42 of Set 8 | ketchikan
# Processing Record 43 of Set 8 | road town
# Processing Record 44 of Set 8 | cidreira
# Processing Record 45 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 46 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 47 of Set 8 | broome
# Processing Record 48 of Set 8 | wick
# Processing Record 49 of Set 8 | itoman
# Processing Record 50 of Set 8 | largo
# Processing Record 1 of Set 9 | luderitz
# Processing Record 2 of Set 9 | bushehr
# Processing Record 3 of Set 9 | padang
# Processing Record 4 of Set 9 | vammala
# Processing Record 5 of Set 9 | viru
# Processing Record 6 of Set 9 | clyde river
# Processing Record 7 of Set 9 | lida
# Processing Record 8 of Set 9 | maturin
# Processing Record 9 of Set 9 | antofagasta
# Processing Record 10 of Set 9 | phalaborwa
# Processing Record 11 of Set 9 | kurilsk
# Processing Record 12 of Set 9 | moses lake
# Processing Record 13 of Set 9 | hasaki
# Processing Record 14 of Set 9 | chernyshevsk
# Processing Record 15 of Set 9 | beira
# Processing Record 16 of Set 9 | guerrero negro
# Processing Record 17 of Set 9 | boueni
# Processing Record 18 of Set 9 | amapa
# Processing Record 19 of Set 9 | zeya
# Processing Record 20 of Set 9 | bayan
# Processing Record 21 of Set 9 | payyannur
# Processing Record 22 of Set 9 | alekseyevsk
# Processing Record 23 of Set 9 | kinanah
# City not found. Skipping...
# Processing Record 24 of Set 9 | college
# Processing Record 25 of Set 9 | yakeshi
# Processing Record 26 of Set 9 | bathsheba
# Processing Record 27 of Set 9 | chicama
# Processing Record 28 of Set 9 | kirakira
# Processing Record 29 of Set 9 | teguise
# Processing Record 30 of Set 9 | okhotsk
# Processing Record 31 of Set 9 | cayenne
# Processing Record 32 of Set 9 | jizan
# Processing Record 33 of Set 9 | pimentel
# Processing Record 34 of Set 9 | san cristobal
# Processing Record 35 of Set 9 | bowen
# Processing Record 36 of Set 9 | pontal do parana
# Processing Record 37 of Set 9 | yamada
# Processing Record 38 of Set 9 | waterville
# Processing Record 39 of Set 9 | los llanos de aridane
# Processing Record 40 of Set 9 | anadyr
# Processing Record 41 of Set 9 | znamenskoye
# Processing Record 42 of Set 9 | salinas
# Processing Record 43 of Set 9 | mapiripan
# Processing Record 44 of Set 9 | olafsvik
# Processing Record 45 of Set 9 | paamiut
# Processing Record 46 of Set 9 | eston
# Processing Record 47 of Set 9 | mahibadhoo
# Processing Record 48 of Set 9 | ha giang
# Processing Record 49 of Set 9 | sungaipenuh
# Processing Record 50 of Set 9 | goure
# Processing Record 1 of Set 10 | eyl
# Processing Record 2 of Set 10 | tateyama
# Processing Record 3 of Set 10 | watrous
# Processing Record 4 of Set 10 | miandrivazo
# Processing Record 5 of Set 10 | zajecar
# Processing Record 6 of Set 10 | vestmanna
# Processing Record 7 of Set 10 | bagdarin
# Processing Record 8 of Set 10 | jackson
# Processing Record 9 of Set 10 | taksimo
# Processing Record 10 of Set 10 | okha
# Processing Record 11 of Set 10 | suntar
# Processing Record 12 of Set 10 | celestun
# Processing Record 13 of Set 10 | toguchin
# Processing Record 14 of Set 10 | voi
# Processing Record 15 of Set 10 | baykit
# Processing Record 16 of Set 10 | la macarena
# Processing Record 17 of Set 10 | mackenzie
# Processing Record 18 of Set 10 | maltahohe
# Processing Record 19 of Set 10 | envira
# Processing Record 20 of Set 10 | mundi
# Processing Record 21 of Set 10 | jalu
# Processing Record 22 of Set 10 | kholodnyy
# Processing Record 23 of Set 10 | tamandare
# Processing Record 24 of Set 10 | mbandaka
# Processing Record 25 of Set 10 | flateby
# Processing Record 26 of Set 10 | ravar
# Processing Record 27 of Set 10 | bindura
# Processing Record 28 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 10 | porto nacional
# Processing Record 31 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 10 | richards bay
# Processing Record 33 of Set 10 | manresa
# Processing Record 34 of Set 10 | pangai
# Processing Record 35 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 36 of Set 10 | nikolsk
# Processing Record 37 of Set 10 | shingu
# Processing Record 38 of Set 10 | dubrovnik
# Processing Record 39 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 10 | thunder bay
# Processing Record 41 of Set 10 | presidencia roque saenz pena
# Processing Record 42 of Set 10 | ancud
# Processing Record 43 of Set 10 | feijo
# Processing Record 44 of Set 10 | codrington
# Processing Record 45 of Set 10 | nemuro
# Processing Record 46 of Set 10 | wukari
# Processing Record 47 of Set 10 | saint-pierre
# Processing Record 48 of Set 10 | taunggyi
# Processing Record 49 of Set 10 | kamina
# Processing Record 50 of Set 10 | dovolnoye
# Processing Record 1 of Set 11 | keita
# Processing Record 2 of Set 11 | pravdinsk
# Processing Record 3 of Set 11 | saint-georges
# Processing Record 4 of Set 11 | aluksne
# Processing Record 5 of Set 11 | nanortalik
# Processing Record 6 of Set 11 | port hardy
# Processing Record 7 of Set 11 | henties bay
# Processing Record 8 of Set 11 | romny
# Processing Record 9 of Set 11 | clovis
# Processing Record 10 of Set 11 | kahului
# Processing Record 11 of Set 11 | ugoofaaru
# Processing Record 12 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 13 of Set 11 | pasni
# Processing Record 14 of Set 11 | san pedro
# Processing Record 15 of Set 11 | stornoway
# Processing Record 16 of Set 11 | manacor
# Processing Record 17 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 11 | mahajanga
# Processing Record 19 of Set 11 | yanam
# Processing Record 20 of Set 11 | vestmannaeyjar
# Processing Record 21 of Set 11 | virginia beach
# Processing Record 22 of Set 11 | pingzhuang
# Processing Record 23 of Set 11 | guilin
# Processing Record 24 of Set 11 | tarauaca
# Processing Record 25 of Set 11 | yeppoon
# Processing Record 26 of Set 11 | arvika
# Processing Record 27 of Set 11 | andenes
# Processing Record 28 of Set 11 | george
# Processing Record 29 of Set 11 | lashio
# Processing Record 30 of Set 11 | saryg-sep
# Processing Record 31 of Set 11 | kihei
# Processing Record 32 of Set 11 | hervey bay
# Processing Record 33 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 34 of Set 11 | rodrigues alves
# Processing Record 35 of Set 11 | mount gambier
# Processing Record 36 of Set 11 | benfleet
# Processing Record 37 of Set 11 | hoquiam
# Processing Record 38 of Set 11 | goianapolis
# Processing Record 39 of Set 11 | berzence
# Processing Record 40 of Set 11 | finnsnes
# Processing Record 41 of Set 11 | great bend
# Processing Record 42 of Set 11 | pilar
# Processing Record 43 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 11 | crotone
# Processing Record 45 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 11 | saravan
# Processing Record 47 of Set 11 | verkhniye tatyshly
# Processing Record 48 of Set 11 | ammon
# Processing Record 49 of Set 11 | gamba
# Processing Record 50 of Set 11 | longyearbyen
# Processing Record 1 of Set 12 | puerto penasco
# Processing Record 2 of Set 12 | ikalamavony
# Processing Record 3 of Set 12 | wajir
# Processing Record 4 of Set 12 | kattivakkam
# Processing Record 5 of Set 12 | puro
# Processing Record 6 of Set 12 | sorland
# Processing Record 7 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 12 | pleasanton
# Processing Record 9 of Set 12 | the valley
# Processing Record 10 of Set 12 | okato
# Processing Record 11 of Set 12 | bonanza
# Processing Record 12 of Set 12 | nizhniy kuranakh
# Processing Record 13 of Set 12 | onega
# Processing Record 14 of Set 12 | simiti
# Processing Record 15 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 16 of Set 12 | jinchang
# Processing Record 17 of Set 12 | chabahar
# Processing Record 18 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 12 | palghar
# Processing Record 20 of Set 12 | lakselv
# Processing Record 21 of Set 12 | copiapo
# Processing Record 22 of Set 12 | campoverde
# Processing Record 23 of Set 12 | chingirlau
# Processing Record 24 of Set 12 | kuah
# Processing Record 25 of Set 12 | uige
# Processing Record 26 of Set 12 | llangefni
# Processing Record 27 of Set 12 | rio bueno
# Processing Record 28 of Set 12 | robertsport
# Processing Record 29 of Set 12 | karla
# Processing Record 30 of Set 12 | boffa
# Processing Record 31 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 12 | chateau-thierry
# Processing Record 33 of Set 12 | watertown
# Processing Record 34 of Set 12 | sinfra
# Processing Record 35 of Set 12 | hualmay
# Processing Record 36 of Set 12 | tianpeng
# Processing Record 37 of Set 12 | mecca
# Processing Record 38 of Set 12 | tshikapa
# Processing Record 39 of Set 12 | novo aripuana
# Processing Record 40 of Set 12 | palaiokhora
# City not found. Skipping...
# Processing Record 41 of Set 12 | aquiraz
# Processing Record 42 of Set 12 | delcevo
# Processing Record 43 of Set 12 | broken hill
# Processing Record 44 of Set 12 | bronnoysund
# Processing Record 45 of Set 12 | mulanje
# Processing Record 46 of Set 12 | abu samrah
# Processing Record 47 of Set 12 | buchanan
# Processing Record 48 of Set 12 | antalaha
# Processing Record 49 of Set 12 | marystown
# Processing Record 50 of Set 12 | singarayakonda
# Processing Record 1 of Set 13 | piacabucu
# Processing Record 2 of Set 13 | noyabrsk
# Processing Record 3 of Set 13 | kletnya
# Processing Record 4 of Set 13 | karratha
# Processing Record 5 of Set 13 | saryozek
# Processing Record 6 of Set 13 | maykain
# City not found. Skipping...
# Processing Record 7 of Set 13 | lyubech
# Processing Record 8 of Set 13 | kleck
# City not found. Skipping...
# Processing Record 9 of Set 13 | san jose
# Processing Record 10 of Set 13 | itaqui
# Processing Record 11 of Set 13 | katobu
# Processing Record 12 of Set 13 | popova
# Processing Record 13 of Set 13 | susehri
# Processing Record 14 of Set 13 | dhaka
# Processing Record 15 of Set 13 | mabaruma
# Processing Record 16 of Set 13 | asilah
# Processing Record 17 of Set 13 | enshi
# Processing Record 18 of Set 13 | vao
# Processing Record 19 of Set 13 | samarai
# Processing Record 20 of Set 13 | kiruna
# Processing Record 21 of Set 13 | yazoo city
# Processing Record 22 of Set 13 | yoichi
# Processing Record 23 of Set 13 | trang
# Processing Record 24 of Set 13 | lorengau
# Processing Record 25 of Set 13 | andrews
# Processing Record 26 of Set 13 | isangel
# Processing Record 27 of Set 13 | prince rupert
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bredasdorp -34.5322   20.0403     65.28        88          13
# 1     New Norfolk -42.7826  147.0587     77.88        31           0
# 2           Kapaa  22.0752 -159.3190     80.58        72          40
# 3         Kokkola  63.8385   23.1307     30.92        92          75
# 4      Butaritari   3.0707  172.7902     81.84        76          71
# 5    Saint George  37.1041 -113.5841     54.19        24           0
# 6         Rikitea -23.1203 -134.9692     79.02        72          16
# 7           Pevek  69.7008  170.3133    -23.37        98          27
# 8            Lebu -37.6167  -73.6500     59.22        92           3
# 9  Ribeira Grande  38.5167  -28.7000     61.07        83           9
#
#    Wind Speed Current Description Country                 Date
# 0        5.75          few clouds      ZA  2022-02-07 02:46:25
# 1        3.00           clear sky      AU  2022-02-07 02:46:25
# 2        1.01    scattered clouds      US  2022-02-07 02:43:48
# 3        4.00       broken clouds      FI  2022-02-07 02:46:26
# 4       15.43       moderate rain      KI  2022-02-07 02:46:26
# 5        1.01           clear sky      US  2022-02-07 02:46:27
# 6       18.75          few clouds      PF  2022-02-07 02:46:27
# 7        0.92    scattered clouds      RU  2022-02-07 02:42:02
# 8       15.41           clear sky      CL  2022-02-07 02:42:14
# 9       16.02           clear sky      PT  2022-02-07 02:46:28

# %%
# Reorder column City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bredasdorp      ZA -34.5322   20.0403     65.28        88          13
# 1     New Norfolk      AU -42.7826  147.0587     77.88        31           0
# 2           Kapaa      US  22.0752 -159.3190     80.58        72          40
# 3         Kokkola      FI  63.8385   23.1307     30.92        92          75
# 4      Butaritari      KI   3.0707  172.7902     81.84        76          71
# 5    Saint George      US  37.1041 -113.5841     54.19        24           0
# 6         Rikitea      PF -23.1203 -134.9692     79.02        72          16
# 7           Pevek      RU  69.7008  170.3133    -23.37        98          27
# 8            Lebu      CL -37.6167  -73.6500     59.22        92           3
# 9  Ribeira Grande      PT  38.5167  -28.7000     61.07        83           9
#
#    Wind Speed Current Description
# 0        5.75          few clouds
# 1        3.00           clear sky
# 2        1.01    scattered clouds
# 3        4.00       broken clouds
# 4       15.43       moderate rain
# 5        1.01           clear sky
# 6       18.75          few clouds
# 7        0.92    scattered clouds
# 8       15.41           clear sky
# 9       16.02           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
